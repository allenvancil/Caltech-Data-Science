# %%
import pandas as pd
df = pd.read_csv('movies-db.csv')
df.head()
# Out:
#                  name  year  length_min      genre  average_rating  \
# 0           Toy Story  1995          81  Animation             8.3
# 1               Akira  1998         125  Animation             8.1
# 2  The Breakfast Club  1985          97      Drama             7.9
# 3          The Artist  2011         100    Romance             8.0
# 4        Modern Times  1936          87     Comedy             8.6
#
#    cost_millions  foreign  age_restriction
# 0           30.0        0                0
# 1           10.4        1               14
# 2            1.0        0               14
# 3           15.0        1               12
# 4            1.5        0               10

# %%
df.columns
df.plot()
# Out:
# <AxesSubplot: >

# %%
df['year'].plot(legend=True) #legend = True adds col name to graph
# Out:
# <AxesSubplot: >

# %%
df.plot(x='year', y='cost_millions', kind='scatter', legend=True)
# Out:
# <AxesSubplot: xlabel='year', ylabel='cost_millions'>

# %%
df.plot(title='Sample Plot', figsize=(15, 10)) #make plot bigger and add title
# Out:
# <AxesSubplot: title={'center': 'Sample Plot'}>

# %%
df['year'].plot(kind='box', title='Box Plot')
# Out:
# <AxesSubplot: title={'center': 'Box Plot'}>

# %%
df['year'].plot(kind='hist', title='Histogram Plot')
# Out:
# <AxesSubplot: title={'center': 'Histogram Plot'}, ylabel='Frequency'>
